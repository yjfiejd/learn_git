# %%
import json

# %%
json_path = "/Users/synyi/Documents/2018.9/9_28_胸科/Archive/annotation38125-38225.json"

# %%
with open(json_path, "r") as f:
    json_file = json.load(f)

# %%
json_file[0]
# Out:
# {'id': 38125,
# ...
