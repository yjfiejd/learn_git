# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1) 导入需要分析的数据  - loop_nodes_relations

# %%
# 环中所有父节点大于2的节点，所连接的边的集合
all_loop_nodes_and_parents = [[(41, 139), (41, 140), (44, 45), (44, 46), (56, 57), (56, 58)], [(121, 16), (121, 17), (15, 16), (15, 17), (26, 126), (26, 127), (58, 59), (58, 60)], [(119, 17), (119, 18), (16, 17), (16, 18), (27, 124), (27, 125), (159, 52), (159, 158), (58, 59), (58, 60)], [(139, 17), (139, 18), (16, 17), (16, 18), (215, 213), (215, 214), (40, 38), (40, 37), (216, 37), (216, 38), (163, 49), (163, 42), (160, 42), (160, 49), (51, 52), (51, 53), (82, 81), (82, 77), (173, 81), (173, 77), (114, 109), (114, 113), (198, 113), (198, 109)], [], [(132, 19), (132, 20), (18, 19), (18, 20), (212, 210), (212, 211), (59, 60), (59, 61), (189, 219), (189, 188)], [(104, 103), (104, 11), (102, 103), (102, 11), (22, 23), (22, 24), (35, 36), (35, 37)], [(42, 43), (42, 44), (59, 60), (59, 61), (161, 162), (161, 164), (80, 164), (80, 162), (177, 95), (177, 174)], [(21, 23), (21, 24), (22, 24), (22, 23), (43, 44), (43, 45)], [(54, 55), (54, 56), (62, 63), (62, 64), (217, 63), (217, 64), (223, 76), (223, 285), (224, 285), (224, 76), (235, 233), (235, 236), (277, 279), (277, 146)]]
# all_loop_nodes_and_parents

# %%
# 环中所有父节点大于2的节点，所连接的边的relation集合
all_loop_nodes_and_parents_relation = [[{135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}], [{135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}], [{135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {86: '是_的限定'}, {132: '(限定关系)通过..检查发现的结果(例如TI影)'}, {124: '是_的某属性'}, {124: '是_的某属性'}], [{135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {134: '是_的形容'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {134: '是_的形容'}, {124: '是_的某属性'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {134: '是_的形容'}, {135: '是_的主体/上级'}, {134: '是_的形容'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {134: '是_的形容'}, {134: '是_的形容'}, {135: '是_的主体/上级'}], [], [{135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {121: '是_的描述/值'}, {135: '是_的主体/上级'}], [{135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}], [{124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {125: '(指代词)指代了_[严格相等]'}, {125: '(指代词)指代了_[严格相等]'}, {124: '是_的某属性'}, {99: '（远程）是_所承接的主体'}, {99: '（远程）是_所承接的主体'}], [{124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}], [{124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {124: '是_的某属性'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {134: '是_的形容'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}, {134: '是_的形容'}, {135: '是_的主体/上级'}, {121: '是_的描述/值'}, {135: '是_的主体/上级'}, {135: '是_的主体/上级'}]]
all_loop_nodes_and_parents_relation
# Out:
# [[{135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'}],
#  [{135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'}],
#  [{135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {86: '是_的限定'},
#   {132: '(限定关系)通过..检查发现的结果(例如TI影)'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'}],
#  [{135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {134: '是_的形容'},
#   {135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {134: '是_的形容'},
#   {124: '是_的某属性'},
#   {135: '是_的主体/上级'},
#   {135: '是_的主体/上级'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {124: '是_的某属性'},
#   {134: '是_的形容'},
#   {135: '是_的主体/上级'},
#   {134: '是_的形容'},
#   {135: '是_的主体/上级'},
# ...

# %%
# all_loop_nodes_and_parents_relation[0]

# %%
# 转换格式, 把多个[] 合并为一个[]
test_relation = []
for i in all_loop_nodes_and_parents_relation:
    test_relation.extend(i)

# %%
test_relation
# Out:
# [{135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {86: '是_的限定'},
#  {132: '(限定关系)通过..检查发现的结果(例如TI影)'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {134: '是_的形容'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {134: '是_的形容'},
#  {124: '是_的某属性'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {124: '是_的某属性'},
#  {134: '是_的形容'},
#  {135: '是_的主体/上级'},
#  {134: '是_的形容'},
#  {135: '是_的主体/上级'},
#  {135: '是_的主体/上级'},
#  {134: '是_的形容'},
#  {134: '是_的形容'},
# ...

# %%
df = pd.DataFrame(test_relation)
df
# Out:
#       86            99       121     124              125  \
# 0     NaN           NaN      NaN     NaN              NaN
# 1     NaN           NaN      NaN     NaN              NaN
# 2     NaN           NaN      NaN  是_的某属性              NaN
# 3     NaN           NaN      NaN  是_的某属性              NaN
# 4     NaN           NaN      NaN  是_的某属性              NaN
# 5     NaN           NaN      NaN  是_的某属性              NaN
# 6     NaN           NaN      NaN     NaN              NaN
# 7     NaN           NaN      NaN     NaN              NaN
# 8     NaN           NaN      NaN  是_的某属性              NaN
# 9     NaN           NaN      NaN  是_的某属性              NaN
# 10    NaN           NaN      NaN     NaN              NaN
# 11    NaN           NaN      NaN     NaN              NaN
# 12    NaN           NaN      NaN  是_的某属性              NaN
# 13    NaN           NaN      NaN  是_的某属性              NaN
# 14    NaN           NaN      NaN     NaN              NaN
# ...

# %%
df.describe()
# Out:
#           86            99       121     124              125  \
# count       1             2        2      44                2
# unique      1             1        1       1                1
# top     是_的限定  （远程）是_所承接的主体  是_的描述/值  是_的某属性  (指代词)指代了_[严格相等]
# freq        1             2        2      44                2
#
#                              132    134       135
# count                          1      8        36
# unique                         1      1         1
# top     (限定关系)通过..检查发现的结果(例如TI影)  是_的形容  是_的主体/上级
# freq                           1      8        36

# %% [markdown]
# #### 2) 导入需要的数据 - loop_nodes_nodes_tags

# %%
all_node_id_category_name = [{41: {7: '身体结构'}, 44: {7: '身体结构'}, 56: {7: '身体结构'}}, {121: {53: '名词性异常表现'}, 15: {7: '身体结构'}, 26: {7: '身体结构'}, 58: {7: '身体结构'}}, {119: {53: '名词性异常表现'}, 16: {7: '身体结构'}, 27: {7: '身体结构'}, 159: {60: '影像'}, 58: {7: '身体结构'}}, {139: {53: '名词性异常表现'}, 16: {7: '身体结构'}, 215: {7: '身体结构'}, 40: {29: '异常结构'}, 216: {53: '名词性异常表现'}, 163: {60: '影像'}, 160: {60: '影像'}, 51: {7: '身体结构'}, 82: {29: '异常结构'}, 173: {53: '名词性异常表现'}, 114: {29: '异常结构'}, 198: {53: '名词性异常表现'}}, {}, {132: {53: '名词性异常表现'}, 18: {7: '身体结构'}, 212: {7: '身体结构'}, 59: {7: '身体结构'}, 189: {7: '身体结构'}}, {104: {53: '名词性异常表现'}, 102: {7: '身体结构'}, 22: {7: '身体结构'}, 35: {7: '身体结构'}}, {42: {7: '身体结构'}, 59: {7: '身体结构'}, 161: {56: '局部位置'}, 80: {56: '局部位置'}, 177: {10: '趋势和变化'}}, {21: {7: '身体结构'}, 22: {7: '身体结构'}, 43: {7: '身体结构'}}, {54: {7: '身体结构'}, 62: {7: '身体结构'}, 217: {53: '名词性异常表现'}, 223: {53: '名词性异常表现'}, 224: {29: '异常结构'}, 235: {60: '影像'}, 277: {29: '异常结构'}}]
all_node_id_category_name
# Out:
# [{41: {7: '身体结构'}, 44: {7: '身体结构'}, 56: {7: '身体结构'}},
#  {121: {53: '名词性异常表现'}, 15: {7: '身体结构'}, 26: {7: '身体结构'}, 58: {7: '身体结构'}},
#  {119: {53: '名词性异常表现'},
#   16: {7: '身体结构'},
#   27: {7: '身体结构'},
#   159: {60: '影像'},
#   58: {7: '身体结构'}},
#  {139: {53: '名词性异常表现'},
#   16: {7: '身体结构'},
#   215: {7: '身体结构'},
#   40: {29: '异常结构'},
#   216: {53: '名词性异常表现'},
#   163: {60: '影像'},
#   160: {60: '影像'},
#   51: {7: '身体结构'},
#   82: {29: '异常结构'},
#   173: {53: '名词性异常表现'},
#   114: {29: '异常结构'},
#   198: {53: '名词性异常表现'}},
#  {},
#  {132: {53: '名词性异常表现'},
#   18: {7: '身体结构'},
#   212: {7: '身体结构'},
#   59: {7: '身体结构'},
#   189: {7: '身体结构'}},
#  {104: {53: '名词性异常表现'}, 102: {7: '身体结构'}, 22: {7: '身体结构'}, 35: {7: '身体结构'}},
#  {42: {7: '身体结构'},
#   59: {7: '身体结构'},
#   161: {56: '局部位置'},
#   80: {56: '局部位置'},
#   177: {10: '趋势和变化'}},
#  {21: {7: '身体结构'}, 22: {7: '身体结构'}, 43: {7: '身体结构'}},
#  {54: {7: '身体结构'},
#   62: {7: '身体结构'},
#   217: {53: '名词性异常表现'},
#   223: {53: '名词性异常表现'},
# ...

# %%
# 把第二层的 {7:'身体结构'} 所有的 -> 这种找出来统计

# %%
list_0 = []
for i in all_node_id_category_name:
    list_a = []
    for j in i:
        list_a.append(i[j])
    list_0.append(list_a)
    
finnal_node_tag_list = []
for i in list_0:
    finnal_node_tag_list.extend(i)

# %%
finnal_node_tag_list
# Out:
# [{7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {53: '名词性异常表现'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {53: '名词性异常表现'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {60: '影像'},
#  {7: '身体结构'},
#  {53: '名词性异常表现'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {29: '异常结构'},
#  {53: '名词性异常表现'},
#  {60: '影像'},
#  {60: '影像'},
#  {7: '身体结构'},
#  {29: '异常结构'},
#  {53: '名词性异常表现'},
#  {29: '异常结构'},
#  {53: '名词性异常表现'},
#  {53: '名词性异常表现'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {53: '名词性异常表现'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {56: '局部位置'},
#  {56: '局部位置'},
#  {10: '趋势和变化'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {7: '身体结构'},
#  {53: '名词性异常表现'},
#  {53: '名词性异常表现'},
#  {29: '异常结构'},
#  {60: '影像'},
#  {29: '异常结构'}]

# %%
df2 = pd.DataFrame(finnal_node_tag_list)
df2
# Out:
#       7      10    29       53    56   60
# 0   身体结构    NaN   NaN      NaN   NaN  NaN
# 1   身体结构    NaN   NaN      NaN   NaN  NaN
# 2   身体结构    NaN   NaN      NaN   NaN  NaN
# 3    NaN    NaN   NaN  名词性异常表现   NaN  NaN
# 4   身体结构    NaN   NaN      NaN   NaN  NaN
# 5   身体结构    NaN   NaN      NaN   NaN  NaN
# 6   身体结构    NaN   NaN      NaN   NaN  NaN
# 7    NaN    NaN   NaN  名词性异常表现   NaN  NaN
# 8   身体结构    NaN   NaN      NaN   NaN  NaN
# 9   身体结构    NaN   NaN      NaN   NaN  NaN
# 10   NaN    NaN   NaN      NaN   NaN   影像
# 11  身体结构    NaN   NaN      NaN   NaN  NaN
# 12   NaN    NaN   NaN  名词性异常表现   NaN  NaN
# 13  身体结构    NaN   NaN      NaN   NaN  NaN
# 14  身体结构    NaN   NaN      NaN   NaN  NaN
# 15   NaN    NaN  异常结构      NaN   NaN  NaN
# 16   NaN    NaN   NaN  名词性异常表现   NaN  NaN
# 17   NaN    NaN   NaN      NaN   NaN   影像
# 18   NaN    NaN   NaN      NaN   NaN   影像
# 19  身体结构    NaN   NaN      NaN   NaN  NaN
# 20   NaN    NaN  异常结构      NaN   NaN  NaN
# ...

# %%
df2.describe()
# Out:
#           7      10    29       53    56  60
# count     26      1     5       10     2   4
# unique     1      1     1        1     1   1
# top     身体结构  趋势和变化  异常结构  名词性异常表现  局部位置  影像
# freq      26      1     5       10     2   4
